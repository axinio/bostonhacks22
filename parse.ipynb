# %%
from bs4 import BeautifulSoup
import urllib
import urllib.request
import re

# %%
url_bu_class_search = "https://www.bu.edu/phpbin/course-search/search.php?page=w0&pagesize=50&adv=1&nolog=&search_adv_all=&yearsem_adv=2023-SPRG&credits=*&pathway=&hub_match=all&pagesize=-1"
with urllib.request.urlopen(url_bu_class_search) as response:
    html = response.read()

# %%
soup = BeautifulSoup(html, "lxml")
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
content = soup.get_text()

# %%
content_list = content.split("\n\n\n\n\n")

# %%
content_list
# Out:
# ['',
#  '',
#  '\n\n\nBoston University Course Search',
#  'Search our database of over 7,000 courses.\n\nPerform a basic search by entering keywords you would expect to find in the course description or by entering a full course number (example: CAS XX 123).  If you would like to see expected course offerings for a particular semester, select that semester in the drop-down box. If you would like to see all courses expected to be offered in the future, select “Future Semesters.”\nTo perform a more targeted search, select Additional Search Options',
#  '\n\n\n\t\t\t\t\tKeyword or Full Course Number (example: CAS XX 123)',
#  '\n\t\t\t\t\tSemester\n\n\t\t\t\t\t\nFall 2022\nSpring 2023\nFuture Semesters\n\n\n\nSearch\n\n\n\nAdditional Search Options\n\n\n\nSchools/Colleges/Programs\nSelect all of the schools/colleges/programs you’re interested in searching. If all options are unchecked, all schools/colleges/programs will be searched by default.',
# ...

# %%
for content in content_list:
    if "Prereq" in content:
        i = content.index("\n\n\n")
        prereq_line = content[i:]
        for class_name in cls_info_keys:
            name1 = class_name
            name2 = class_name[:3]+class_name[4:6]+class_name[7:]
            name3 = name1.lower()
            name4 = name2.lower()
            name5 = class_name[-6:]
            name6 = class_name[-6:-4]+class_name[-3:]
            name7 = name5.lower()
            name8 = name6.lower()
            if name1 in prereq_line or name2 in prereq_line or name3 in prereq_line or name4 in prereq_line or name5 in prereq_line or name6 in prereq_line or name7 in prereq_line or name8 in prereq_line:
                print(class_name)
# Out:
# CAS WR 120
# CAS WR 120
# CAS EC 101
# CAS EC 363
# CAS HI 489
# CAS WR 120
# CAS WR 120
# CAS WR 120
# CAS AN 101
# CAS AN 102
# CAS WR 120
# MET AN 101
# MET AN 102
# CAS WR 120
# CAS AN 102
# MET AN 102
# CAS AN 102
# MET AN 102
# CAS AN 101
# MET AN 101
# CAS WR 120
# CAS AN 102
# MET AN 102
# CAS AN 101
# CAS AN 102
# MET AN 101
# MET AN 102
# CAS AN 102
# MET AN 102
# CAS WR 120
# CAS AR 100
# CAS AR 190
# CAS MA 124
# CAS PY 212
# CAS PY 252
# MET MA 124
# MET PY 212
# CAS PY 212
# CAS PY 252
# CAS PY 355
# MET PY 212
# CAS AS 312
# CAS WR 120
# CAS BB 140
# CAS BB 240
# CAS BB 340
# CAS BB 350
# CAS BB 140
# CAS BB 240
# CAS BB 340
# CAS BB 350
# CAS BB 341
# CAS BB 351
# CAS WR 120
# CAS BB 402
# CAS BB 498
# CAS WR 120
# CAS BB 140
# CAS BB 240
# CAS BB 340
# CAS BI 350
# CAS BI 450
# CAS BB 341
# CAS BB 351
# CAS BB 451
# CAS WR 120
# CAS BB 352
# CAS BB 498
# CAS WR 120
# CAS BB 592
# CAS BB 591
# CAS CH 101
# CAS CH 116
# CAS WR 120
# MET CH 101
# CAS BI 108
# ...

# %%
prefix = []
HUB_dict = {}
for content in content_list:
    if "\n\t\t\t\t\t\t\t\t\t" in content:
        content = content.replace("\n\t\t\t\t\t\t\t\t", "")
        content = content[2:]
        if len(content)==3:
            prefix.append(content)
#         prefix.append(content)

        if "("in content:
            index_f = content.index("(")
            index_l = content.index(")")
            HUB_dict[content[index_f+1: index_l]] = content[:index_f-1]
            
            
prefix.append("XRG")
prefix.append("XCC")
HUB_dict.pop('XCC')
print(HUB_dict)
prefix
# Out:
# {'PLM': "Philosophical Inquiry and Life's Meanings", 'AEX': 'Aesthetic Exploration', 'HCO': 'Historical Consciousness', 'SI1': 'Scientific Inquiry I', 'SI2': 'Scientific Inquiry II', 'SO1': 'Social Inquiry I', 'SO2': 'Social Inquiry II', 'QR1': 'Quantitative Reasoning I', 'QR2': 'Quantitative Reasoning II', 'IIC': 'The Individual in Community', 'GCI': 'Global Citizenship and Intercultural Literacy', 'ETR': 'Ethical Reasoning', 'FYW': 'First-Year Writing Seminar', 'WRI': 'Writing, Research, and Inquiry', 'WIN': 'Writing-Intensive Course', 'OSC': 'Oral and/or Signed Communication', 'DME': 'Digital/Multimedia Expression', 'CRT': 'Critical Thinking', 'RIL': 'Research and Information Literacy', 'TWC': 'Teamwork/Collaboration', 'CRI': 'Creativity/Innovation'}
# ['CAS',
#  'CDS',
#  'CFA',
#  'CGS',
#  'COM',
#  'ENG',
#  'EOP',
#  'GMS',
#  'GRS',
#  'HUB',
#  'KHC',
#  'LAW',
#  'MED',
#  'MET',
#  'OTP',
#  'PDP',
#  'QST',
#  'SAR',
#  'SDM',
#  'SED',
#  'SHA',
#  'SPH',
#  'SSW',
# ...

# %%
HUB_fullname = list(HUB_dict.values())
HUB_fullname
# Out:
# ["Philosophical Inquiry and Life's Meanings",
#  'Aesthetic Exploration',
#  'Historical Consciousness',
#  'Scientific Inquiry I',
#  'Scientific Inquiry II',
#  'Social Inquiry I',
#  'Social Inquiry II',
#  'Quantitative Reasoning I',
#  'Quantitative Reasoning II',
#  'The Individual in Community',
#  'Global Citizenship and Intercultural Literacy',
#  'Ethical Reasoning',
#  'First-Year Writing Seminar',
#  'Writing, Research, and Inquiry',
#  'Writing-Intensive Course',
#  'Oral and/or Signed Communication',
#  'Digital/Multimedia Expression',
#  'Critical Thinking',
#  'Research and Information Literacy',
#  'Teamwork/Collaboration',
#  'Creativity/Innovation']

# %%
cls_info = {}
for content in content_list:
    cls = content[:11]
    if cls[:3] in prefix:
        cls_info[cls[:-1]] = {}
        
        cls_info[cls[:-1]]["major"]=cls[4:6]
        
        cls_info[cls[:-1]]["HUB"] = []
        for hub in HUB_fullname:
            if hub in content:
                cls_info[cls[:-1]]["HUB"].append(hub)
        
        if "Prereq" in content:
            cls_info[cls[:-1]]["Prereq"] = []
            i = content.index("\n\n\n")
            prereq_line = content[i:]
            for class_name in cls_info_keys:
                name1 = class_name
                name2 = class_name[:3]+class_name[4:6]+class_name[7:]
                name3 = name1.lower()
                name4 = name2.lower()
                name5 = class_name[-6:]
                name6 = class_name[-6:-4]+class_name[-3:]
                name7 = name5.lower()
                name8 = name6.lower()
                if name1 in prereq_line or name2 in prereq_line or name3 in prereq_line or name4 in prereq_line or name5 in prereq_line or name6 in prereq_line or name7 in prereq_line or name8 in prereq_line:
                    cls_info[cls[:-1]]["Prereq"].append(class_name)
                    
print(cls_info)
# Out:
# {'CAS AA 103': {'major': 'AA', 'HUB': ['Global Citizenship and Intercultural Literacy', 'First-Year Writing Seminar', 'Writing-Intensive Course', 'Critical Thinking'], 'Prereq': ['CAS WR 120']}, 'CAS AA 112': {'major': 'AA', 'HUB': []}, 'CAS AA 207': {'major': 'AA', 'HUB': []}, 'CAS AA 215': {'major': 'AA', 'HUB': []}, 'CAS AA 234': {'major': 'AA', 'HUB': []}, 'CAS AA 296': {'major': 'AA', 'HUB': []}, 'CAS AA 308': {'major': 'AA', 'HUB': []}, 'CAS AA 310': {'major': 'AA', 'HUB': []}, 'CAS AA 335': {'major': 'AA', 'HUB': ['Historical Consciousness', 'The Individual in Community', 'Digital/Multimedia Expression'], 'Prereq': []}, 'CAS AA 356': {'major': 'AA', 'HUB': ['First-Year Writing Seminar', 'Writing-Intensive Course', 'Digital/Multimedia Expression', 'Creativity/Innovation'], 'Prereq': ['CAS WR 120']}, 'CAS AA 363': {'major': 'AA', 'HUB': ['Historical Consciousness', 'Social Inquiry I', 'Social Inquiry II'], 'Prereq': ['CAS EC 101', 'CAS EC 363']}, 'CAS AA 385': {'major': 'AA', 'H
# ...

# %%
x = {"a":{"b":"c"}}
print(list(x["a"].values()))
# Out:
# ['c']

# %%
for inner_url in link_lst[1:10]:
    req = urllib.request.Request(inner_url, headers={'User-Agent': 'Mozilla/5.0'})
    html2 = urllib.request.urlopen(req).read()
    soup2 = BeautifulSoup(html2, "lxml")
    content = soup2.get_text()
    class_name = content[69:79]
        
    if class_name[-3:].isnumeric():
        cls_info[class_name]["section"] = {}
        
        num_of_LEC = content.count("LEC") + content.count("IND")
        print(num_of_LEC)
        for num in range(num_of_LEC):
            sect = chr(65+num)+str(1)
            print(sect)
            if sect in content:
                print("class_name", class_name)
                index = content.index(sect)
                time_list = content[index:].split()
                time_schdeule = time_list[3]+time_list[4]+time_list[5][:2]
                if len(time_schdeule)<=15:
                    cls_info[class_name]["section"][sect] = time_schdeule
                    print(time_schdeule)

print(cls_info)
# Out:
# 1
# A1
# class_name CAS AA 103
# 10:10am-11:00am
# 1
# A1
# class_name CAS AA 112
# 12:30pm-1:45pm
# 1
# A1
# class_name CAS AA 207
# 9:30am-10:45am
# 1
# A1
# class_name CAS AA 215
# 5:00pm-6:15pm
# 1
# A1
# class_name CAS AA 234
# 9:30am-10:45am
# 1
# A1
# class_name CAS AA 296
# 9:30am-10:45am
# 1
# A1
# class_name CAS AA 308
# 1
# A1
# class_name CAS AA 310
# 11:00am-12:15pm
# 1
# A1
# class_name CAS AA 335
# 12:30pm-3:15pm
# ...

# %%
cls_info_keys = list(cls_info.keys())
cls_info_keys.index("STH TZ 999")
# Out:
# 4073

# %%
link_lst = []
for link in soup.find_all("a"):
    if "/phpbin" in link.get('href'):
        link_lst.append("https://www.bu.edu"+link.get('href'))

# %%
len(link_lst)
# Out:
# 4078

# %%
abc = []
for inner_url in link_lst[4073:-3]:
    with urllib.request.urlopen(inner_url) as response:
        html2 = response.read()
    soup = BeautifulSoup(html2, "lxml")
    content = soup.get_text()
    class_name = content[69:79]
    num_of_LEC = content.count("LEC") + content.count("IND")
    
    
    
    if "A1" in content:
        index = content.index("A1")
        print(class_name)
        time_list = content[index:].split()
        time_schdeule = time_list[3]+time_list[4]+time_list[5][:2]
        print(time_schdeule)

    abc.append(content)
abc
# Out:
# STH TZ 911
# 0:am01/19-05/03WebRegRe
# ...
